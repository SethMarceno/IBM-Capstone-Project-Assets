# %%
import matplotlib.pyplot as plt
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_b34c7f20d5ab41bf83daf8fc0161401e = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='WTQUTAc2oYsJdDBkESk0NhqZQVSbNlkvTKmmYr03F9fQ',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_b34c7f20d5ab41bf83daf8fc0161401e.get_object(Bucket='ibmdataanalystcapstoneproject-donotdelete-pr-aiuqmjz4mvhlyb',Key='github-job-postings.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1
# Out:
#         Language  Job Postings
# 0              C           218
# 1             C#            50
# 2            C++           218
# 3           Java           134
# 4     JavaScript           107
# 5         Python            94
# 6          Scala            96
# 7         Oracle             8
# 8     SQL Server            24
# 9   MySQL Server             4
# 10    PostgreSQL            24
# 11       MongoDB            14

# %%
df = df_data_1
df.sort_values(by='Job Postings', ascending=False, axis=0, inplace=True)
df
# Out:
#         Language  Job Postings
# 0              C           218
# 2            C++           218
# 3           Java           134
# 4     JavaScript           107
# 6          Scala            96
# 5         Python            94
# 1             C#            50
# 8     SQL Server            24
# 10    PostgreSQL            24
# 11       MongoDB            14
# 7         Oracle             8
# 9   MySQL Server             4

# %%
df.plot(kind='bar', x='Language', figsize=(14, 7))

plt.title('Github Job Postings With Programming Language Requirements')
plt.xlabel('Language')
plt.ylabel('Number of Postings')

plt.show()
